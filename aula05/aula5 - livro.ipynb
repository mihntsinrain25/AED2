# %% [markdown]
# # **EXERCÍCIOS DO LIVRO**

# %% [markdown]
# ## **CÁPITULO 5**

# %% [markdown]
# ---

# %% [markdown]
# **Exercício 1:** Encapsulamento e acesso a dados: Considere que um desenvolvedor criou uma classe Pessoa com um atributo __idade. Sobre o acesso e uso desse atributo, qual das afirmações é correta?
#
# a) Como __idade é privado, ele não pode ser alterado nem mesmo por métodos dentro da classe.
#
# b) O atributo __idade pode ser lido e modificado livremente fora da classe, já que Python não possui encapsulamento real.
#
# c) O atributo __idade só deve ser acessado através de métodos da classe (por exemplo, um getter e/ou setter), pois não é acessível diretamente de fora devido ao encapsulamento implementado pelo nome.
#
# d) Em Python, __idade e _idade (um underscore) têm o mesmo efeito – ambos são públicos.

# %% [markdown]
# **RESPOSTA:** c) O atributo __idade só deve ser acessado através de métodos da classe (por exemplo, um getter e/ou setter), pois não é acessível diretamente de fora devido ao encapsulamento implementado pelo nome.

# %% [markdown]
# ---

# %% [markdown]
# **Exercício 2:** Pilares da POO: A seguinte situação é descrita: "Uma classe base Veiculo define um método mover(). Duas subclasses, Carro e Barco, implementam mover() de formas diferentes. Em uma parte do programa, uma função recebe um objeto Veiculo e chama obj.mover(), sem saber se é Carro ou Barco – ainda assim, o comportamento correto acontece." Essa situação ilustra principalmente qual pilar da orientação a objetos?
#
# a) Abstração
#
# b) Encapsulamento
#
# c) Herança
#
# d) Polimorfismo

# %% [markdown]
# **RESPOSTA:** d) Polimorfismo

# %% [markdown]
# ---

# %% [markdown]
# **Exercício 3:** Comparando paradigmas: Qual das opções melhor diferencia a programação procedural da programação orientada a objetos?
#
# a) Na programação procedural, usa-se funções; na orientada a objetos, não existem funções.
#
# b) A programação orientada a objetos organiza o código em classes/objetos que combinam estado e comportamento, enquanto a procedural organiza o código em rotinas (funções) separadas dos dados.
#
# c) A programação procedural é sempre menos eficiente que a orientada a objetos.
#
# d) A orientação a objetos não permite estrutura de controle como loops e condicionais, ao contrário do procedural.

# %% [markdown]
# **RESPOSTA:** b) A programação orientada a objetos organiza o código em classes/objetos que combinam estado e comportamento, enquanto a procedural organiza o código em rotinas (funções) separadas dos dados.

# %% [markdown]
# ____

# %% [markdown]
# **Exercício 4:** Conceitos de Python: Em relação à POO em Python, assinale a alternativa incorreta:
#
# a) É possível criar atributos que sejam exclusivos da classe (estáticos), compartilhados entre todas as instâncias.
#
# b) O método __str__ de uma classe, quando implementado, define o que print(obj) exibirá para objetos daquela classe.
#
# c) A herança em Python não suporta mais de uma classe base; cada classe só pode herdar de no máximo uma superclasse.
#
# d) Mesmo sem usar modificadores de acesso explícitos, é prática comum usar convenções como _atributo e __atributo para indicar níveis de acesso (semiprivado/privado).

# %% [markdown]
# **RESPOSTA:** c) A herança em Python não suporta mais de uma classe base; cada classe só pode herdar de no máximo uma superclasse.

# %% [markdown]
# ---

# %% [markdown]
# **Exercício 5:** (PRÁTICA) Classe Pessoa: Crie uma classe Pessoa com nome e idade. Adicione método
# faz_aniversario() que incrementa a idade em 1. Use __str__() para retornar algo como "<nome>, <idade> anos". Crie duas pessoas e mostre a idade de cada uma antes e depois de chamar faz_aniversario().

# %%
'''RESPOSTA'''

class Pessoa:
    def __init__ (self, nome, idade):
        self.nome = nome
        self.idade = idade
    def faz_aniversario(self):
        self.idade += 1
    def __str__ (self):
        return f"{self.nome}, {self.idade} anos."

pessoa1 = Pessoa("Amanda", 35)
pessoa2= Pessoa("Renato", 32)

Aniversario = "Antes do Aniversario"
Depois = "Depois do Aniversario"
print(Aniversario)
print(pessoa1)
print(pessoa2)

pessoa1.faz_aniversario()
pessoa2.faz_aniversario()

print("-" * len(Aniversario))

print("Depois do Aniversario")
print(pessoa1)
print(pessoa2)
print("-" * len(Depois))
# Out:
# Antes do Aniversario
# Amanda, 35 anos.
# Renato, 32 anos.
# --------------------
# Depois do Aniversario
# Amanda, 36 anos.
# Renato, 33 anos.
# ---------------------

# %% [markdown]
# ---

# %% [markdown]
# **Exercício 6:** (PRÁTICA): Encapsulamento: Dada a classe abaixo sem encapsulamento, implemente encapsulamento adequado:

# %%
class Lampada: 
    def __init__(self): 
        self.estado = False 
    def ligar(self): 
        self.estado = True 
    def desligar(self): 
        self.estado = False

# %% [markdown]
# Modifique para que o atributo estado seja privado e só possa ser alterado pelos métodos ligar() e desligar(). Adicione métodos is_acesa() para verificar o estado.

# %%
'''RESPOSTA'''

class lampada: 
    def __init__(self): 
        self._estado = False 
    def ligar(self): 
        self._estado = True 
    def desligar(self): 
        self._estado = False
    def is_acesa(self):
        return self._estado

lampada = lampada()


print("A lampada está acesa?", lampada.is_acesa())
lampada.ligar()
print("A lampada está acesa?", lampada.is_acesa())
lampada.desligar()
print("A lampada está acesa?", lampada.is_acesa())
# Out:
# A lampada está acesa? False
# A lampada está acesa? True
# A lampada está acesa? False

# %% [markdown]
# ---

# %% [markdown]
# **Exercício 7:** (PRÁTICA): Herança: Implemente duas classes com herança:
#
# • Classe base Animal com um método fazer_som() que imprime algo genérico, por exemplo "Algum som".
#
# • Duas subclasses Cachorro e Gato que herdam de Animal. Na classe Cachorro, sobrescreva fazer_som() para imprimir "Au Au". Em Gato, para "Miau". Crie um objeto de cada e chame fazer_som() em cada um.

# %%
'''RESPOSTA'''

class Animal:
    def fazer_som(self):
        print("Hakunamatata")
class Cachorro(Animal):
    def fazer_som(self):
        print("Au Au")
class Gato(Animal):
    def fazer_som(self):
        print("Miau")


animal = Animal()
cachorro = Cachorro()
gato = Gato()

print("O cachorro faz:", end =" ")
cachorro.fazer_som()
print("O gato faz:", end =" ")
gato.fazer_som()
print("E qualquer animal diz:", end=" ")
animal.fazer_som()
# Out:
# O cachorro faz: Au Au
# O gato faz: Miau
# E qualquer animal diz: Hakunamatata

# %% [markdown]
# ---

# %% [markdown]
# **Exercício 8:** (PRÁTICA): Polimorfismo: Dada as classes do Exercício 4, escreva uma função externa animais_falam(lista_animais) que recebe uma lista de objetos (que podem ser Cachorro ou Gato) e chama fazer_som() em cada um. Mostre que a função pode operar sobre diferentes tipos de animais (polimorfismo em ação).

# %%
'''RESPOSTA'''

def animais_falam(lista_animais):
    for animal in lista_animais:
        animal.fazer_som()
cachorro = Cachorro()
gato = Gato()
animal = Animal()
lista = [animal, cachorro , gato]
animais_falam(lista)
# Out:
# Hakunamatata
# Au Au
# Miau

# %% [markdown]
# ---

# %% [markdown]
# # **Projeto**

# %% [markdown]
# ### **Projeto 1: Biblioteca de Livros**
#
# - **Contexto do mundo real**: Imagine um sistema para gerenciar o empréstimo de livros em uma pequena biblioteca escolar. Queremos cadastrar livros e usuários, registrar quando alguém empresta ou devolve um livro.
# - **Descrição do problema**: Cada Livro tem título, autor, quantidade disponível. Cada Usuário tem nome, matrícula e lista de livros emprestados. O sistema deve permitir que um usuário faça empréstimos (reduzindo a quantidade disponível) e devoluções (aumentando quantidade). Devemos evitar empréstimos se o livro estiver indisponível. Também precisamos manter os dados organizados e seguros (ex.: não permitir mexer diretamente na quantidade disponível).

# %%
class Livro:
    def __init__(self, titulo, autor, quantidade):
        self.titulo = titulo
        self.autor = autor
        self.__quantidade = quantidade

    def emprestar(self):
        if self.__quantidade > 0:
            self.__quantidade-= 1
            return True
        return False

    def devolver(self):
        self.__quantidade += 1

    def get_quantidade(self):
        return self.__quantidade


class Usuario:
    def __init__ (self, nome, matricula):
        self.nome = nome
        self.matricula = matricula 
        self.livros_emprestados = []

    def emprestar_livro(self, livro):
        if livro.emprestar():
            self.livros_emprestados.append(livro.titulo)
            print(f"{self.nome} pegou '{livro.titulo}'")
        else:
            print("Livro indisponivel!!")

    def devolver_livro(self, livro):
        if livro.titulo in self.livros_emprestados:
            livro.devolver()
            self.livros_emprestados.remove(livro.titulo)
            print(f"{self.nome} devolveu '{livro.titulo}'")
        else:
            print(f"{self.nome} não está com '{livro.titulo}'")

# %%
livro1 = Livro("1984", "George Orwell", 2)
user1 = Usuario("Mirella", 123)

user1.emprestar_livro(livro1)
user1.emprestar_livro(livro1)
user1.emprestar_livro(livro1)  # é pra dar indisponível

user1.devolver_livro(livro1)
# Out:
# Mirella pegou '1984'
# Mirella pegou '1984'
# Livro indisponivel!!
# Mirella devolveu '1984'

# %% [markdown]
# ---

# %% [markdown]
# ### **Projeto 2: Gerenciamento de Conta Bancária com Herança**
#
# - **Contexto do mundo real**: Um banco que oferece dois tipos de conta: conta corrente e conta poupança. Queremos um sistema que permita depositar, sacar e aplicar juros (no caso da poupança).
# - **Descrição do problema**: Precisamos modelar contas bancárias em Python de forma orientada a objetos.
#
# Teremos:
#
# - Classe base Conta com atributos comuns (titular, saldo) e métodos depositar(valor) e sacar(valor).
#
# - Classe ContaCorrente que herda de Conta e adiciona, por exemplo, taxa de saque (ou limite especial).
#
# - Classe ContaPoupanca que herda de Conta e tem um método extra render_juros() que aumenta o saldo de acordo com uma taxa fixa anual.
# Também podemos manter atributos de classe (como juros = 0.05 para 5% ao ano).

# %%
class Conta:
    def __init__(self, titular, saldo):
        self.titular = titular
        self.saldo = saldo

    def depositar(self, valor):
        self.saldo += valor
        print(f"Depósito de {valor} realizado. Saldo: {self.saldo}")

    def sacar(self, valor):
        if self.saldo >= valor:
            self.saldo -= valor
            print(f"Saque de {valor} realizado. Saldo: {self.saldo}")
        else:
            print("Saldo insuficiente!")


class ContaCorrente(Conta):
    def __init__(self, titular, saldo, taxa_saque):
        super().__init__(titular, saldo)
        self.taxa_saque = taxa_saque

    def sacar(self, valor):
        total = valor + self.taxa_saque
        if self.saldo >= total:
            self.saldo -= total
            print(f"Saque de {valor} + taxa {self.taxa_saque}. Saldo: {self.saldo}")
        else:
            print("Saldo insuficiente para saque com taxa!")


class ContaPoupanca(Conta):
    juros = 0.05  # 5% ao ano (atributo de classe)

    def render_juros(self):
        ganho = self.saldo * ContaPoupanca.juros
        self.saldo += ganho
        print(f"Juros aplicados: {ganho}. Saldo: {self.saldo}")

# %%
conta1 = ContaCorrente("Humberto", 1000, 5)
conta2 = ContaPoupanca("Humberto", 1000)

conta1.depositar(200)
conta1.sacar(100)

conta2.depositar(300)
conta2.render_juros()
# Out:
# Depósito de 200 realizado. Saldo: 1200
# Saque de 100 + taxa 5. Saldo: 1095
# Depósito de 300 realizado. Saldo: 1300
# Juros aplicados: 65.0. Saldo: 1365.0
